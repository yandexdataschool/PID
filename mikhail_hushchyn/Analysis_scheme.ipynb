# %% [markdown]
# # LHCb Particle Identification

# %% [markdown]
# # Authors

# %% [markdown]
# Andrey Ustyuzhanin, YSDA, HSE <br>
# Denis Derkach, YSDA, HSE <br>
# Tatiana Likhomanenko, YSDA, HSE <br>
# Mikhail Hushchyn, YSDA, MIPT <br>
# Eltyshev Evgenii, YSDA, MIPT <br>
# Sergei Korolev, YSDA, HSE <br>
# Dmitry Petrov, YSDA, HSE <br>

# %% [markdown]
# # Multiclass Neural Network

# %% [markdown]
# For the baseline repeating the following configuration was choosen:
#
# *Train config:* TrainPhysTks-EvalPhysTks-NoReweight <br>
# *Net config:* TMVA-Run2-NoTkLikCDVelodEdx <br>
# *GhostAccFrac:* 1.0 <br>
# *Training data:* Mixture <br>
# *Data files:* MC2015Sim09Dev03 <br>

# %% [markdown]
# ## Keras Neural Networks

# %% [markdown]
# Data was balanced
#
# A list of the classifier's parameters is shown below:
#
# *features:*  <br>
# [ 'BremPIDe',
#  'CaloNeutralPrs',
#  'CaloNeutralSpd',
#  'InAccBrem',
#  'InAccSpd',
#  'CaloPrsE',
#  'InAccPrs',
#  'HcalPIDe',
#  'CaloHcalE',
#  'InAccHcal',
#  'CaloTrajectoryL',
#  'EcalPIDe',
#  'CaloNeutralEcal',
#  'CaloTrMatch',
#  'CaloElectronMatch',
#  'CaloChargedPrs',
#  'CaloChargedSpd',
#  'MuonNShared',
#  'CaloBremMatch',
#  'MuonIsLooseMuon',
#  'MuonIsMuon',
#  'MuonBkgLL',
#  'InAccEcal',
#  'MuonMuLL',
#  'TrackGhostProbability',
#  'TrackType',
#  'EcalPIDmu',
#  'TrackPt',
#  'TrackP',
#  'RichAboveMuThres',
#  'InAccMuon',
#  'TrackChi2PerDof',
#  'TrackNumDof',
#  'CombDLLmu',
#  'CaloSpdE',
#  'PrsPIDe',
#  'HcalPIDmu',
#  'TrackFitMatchChi2',
#  'CombDLLpi',
#  'RichDLLbt',
#  'TrackHistory',
#  'RichDLLpi',
#  'TrackFitVeloNDoF',
#  'CombDLLp',
#  'TrackFitTChi2',
#  'TrackFitTNDoF',
#  'RichAboveElThres',
#  'TrackDOCA',
#  'RichDLLe',
#  'CombDLLe',
#  'CombDLLk',
#  'TrackFitVeloChi2',
#  'RichDLLp',
#  'RichUsedR1Gas',
#  'RichUsedR2Gas',
#  'CaloEcalE',
#  'RichAbovePiThres',
#  'CaloChargedEcal',
#  'RichAboveKaThres',
#  'RichAbovePrThres',
#  'RichDLLmu',
#  'RichDLLk'
#  'piplus_OWNPV_X',
#  'piplus_OWNPV_Y',
#  'piplus_OWNPV_Z',
#  'piplus_OWNPV_XERR',
#  'piplus_OWNPV_YERR',
#  'piplus_OWNPV_ZERR',
#  'piplus_OWNPV_CHI2',
#  'piplus_OWNPV_NDOF',
#  'piplus_IP_OWNPV',
#  'piplus_IPCHI2_OWNPV'] <br>
#    <br>
#
# Params look in the IPython notebook below.
#
# **IPython notebook:** [notebook](https://github.com/yandexdataschool/PID/blob/733d8c94f9af73dc528840fc25cda359455acbb2/mikhail_hushchyn/neural_nets.ipynb)
#
# **Directory with model and figures:** [directory](https://github.com/yandexdataschool/PID/tree/master/mikhail_hushchyn/baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002)

# %% [markdown]
# ## Overall quality

# %%
import numpy
work_path = "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/\
multiclass/Long/Keras/002/"
logloss = numpy.loadtxt(work_path + '/logloss_eval.csv')
print "Log loss is ", logloss
# Out:
# Log loss is  0.610104412687

# %% [markdown]
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/overall_roc_auc.png" /> <br>
#
#
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/class_vs_class_roc_auc_matrix.png" />
#
#
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Ghost_vs_one_roc_auc.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Electron_vs_one_roc_auc.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Muon_vs_one_roc_auc.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Pion_vs_one_roc_auc.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Kaon_vs_one_roc_auc.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Proton_vs_one_roc_auc.png" /></td>
#
# </tr>
# </tbody>
# </table>

# %%
import pandas
pandas.set_option('display.precision',3)
matrix = pandas.read_csv(work_path + "class_vs_class_roc_auc_matrix.csv", index_col=0)
particles = ['Electron', 'Proton', 'Pion', 'Muon', 'Kaon', 'Ghost']
matrix
# Out:
#           Ghost  Electron   Muon   Pion   Kaon  Proton
# Ghost     1.000     0.973  0.995  0.968  0.984   0.982
# Electron  0.973     1.000  0.999  0.995  0.997   0.997
# Muon      0.995     0.999  1.000  0.993  0.996   0.997
# Pion      0.968     0.995  0.993  1.000  0.959   0.958
# Kaon      0.984     0.997  0.996  0.959  1.000   0.805
# Proton    0.982     0.997  0.997  0.958  0.805   1.000

# %% [markdown]
# # The quality with respect to the baseline
#
# $$
# Ratio = \frac{Roc\_Auc\_of\_this\_solution}{Roc\_Auc\_of\_the\_baseline}
# $$

# %% [markdown]
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/class_vs_class_roc_auc_rel_matrix.png" />

# %%
import pandas
pandas.set_option('display.precision',3)
rel_matrix = pandas.read_csv(work_path + "class_vs_class_roc_auc_rel_matrix.csv", index_col=0)
rel_matrix
# Out:
#           Ghost  Electron   Muon   Pion   Kaon  Proton
# Ghost     1.000     1.020  1.003  1.008  1.007   1.007
# Electron  1.020     1.000  1.003  1.018  1.012   1.012
# Muon      1.003     1.003  1.000  1.005  1.003   1.003
# Pion      1.008     1.018  1.005  1.000  1.004   1.004
# Kaon      1.007     1.012  1.003  1.004  1.000   1.023
# Proton    1.007     1.012  1.003  1.004  1.023   1.000

# %% [markdown]
# $$
# Ratio = (1 - \frac{1 - Roc\_Auc\_of\_this\_solution}{1- Roc\_Auc\_of\_the\_baseline}) * 100\%
# $$

# %% [markdown]
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/class_vs_class_roc_aoc_rel_matrix.png" />

# %%
import pandas
pandas.set_option('display.precision',3)
rel_matrix = pandas.read_csv(work_path + "class_vs_class_roc_aoc_rel_matrix.csv", index_col=0)
rel_matrix
# Out:
#            Ghost  Electron    Muon    Pion    Kaon  Proton
# Ghost        NaN    40.851  40.417  19.123  30.306  28.149
# Electron  40.852       NaN  75.911  78.477  80.873  80.591
# Muon      40.418    75.889     NaN  41.683  45.792  49.842
# Pion      19.123    78.174  41.564     NaN   8.111   7.932
# Kaon      30.306    80.911  45.788   8.110     NaN   8.417
# Proton    28.149    80.584  49.843   7.930   8.417     NaN

# %% [markdown]
# # Cramer–von Mises test
#
# We use Cramer–von Mises (CvM) test to measure correlation between MVA Output and momentum/transverse momentum for signal particle.
#
# The correlation between MVA Output and momentum/transverse momentum for a signal particle is absent with confidence of 95 % if the CvM value for the particle less than appropriate CvM confidence value. The confidence values for the each particle are presented in the table below.
#
# For computing CvM metric the global predictions CDF is compared to
# a local (in some momentum/transverse momentum interval) predictions CDF. After that all intervals are
# averaged:
#
# $$
# CvM_{\text{interval}} = \int (F_{\text{global}} - F_{\text{interval}})^2 \, d\, F_{global}
# $$
# <br>
# $$
# CvM = <CvM_{\text{interval}}>_{\text{interval}}
# $$
#
# where $F_{global}$, $F_{\text{interval}}$ are predictions cumulative distribution functions
# for all data and data in some momentum/transverse momentum interval corresponding
#
# ### References:
# 1. https://kaggle2.blob.core.windows.net/competitions/kaggle/4488/media/lhcb_description_official.pdf , p.8
# 2. https://en.wikipedia.org/wiki/Cramér–von_Mises_criterion
# 3. https://indico.cern.ch/event/433556/session/1/contribution/7/attachments/1230891/1804264/Rogozhnikov_boosting_in_HEP.pdf p.25-26

# %% [markdown]
# ### CvM tests and 95% confidence values for signal particles

# %%
flatness = pandas.read_csv(work_path + "flatness.csv", index_col=0)
#pandas.set_option('display.precision',3)
cols = ['TrackP', 'P_Conf_level', 'TrackPt', 'Pt_Conf_level']
flatness[cols] = flatness[cols].round(3)
flatness
# Out:
#           TrackP  TrackPt  P_Conf_level  Pt_Conf_level
# Ghost      0.005    0.023         0.001          0.001
# Electron   0.011    0.036         0.001          0.001
# Muon       0.023    0.037         0.001          0.001
# Pion       0.016    0.015         0.001          0.001
# Kaon       0.046    0.030         0.001          0.001
# Proton     0.036    0.044         0.001          0.001

# %% [markdown]
# # The CvM tests with respect to the baseline
#
# $$
# Ratio = \frac{CvM\_tests\_for\_this\_solution}{CvM\_tests\_for\_the\_baseline}
# $$

# %%
rel_flatness = pandas.read_csv(work_path + "rel_flatness.csv", index_col=0)
#pandas.set_option('display.precision',3)
rel_cols = ['TrackP', 'TrackPt']
rel_flatness = rel_flatness.round(3)
rel_flatness
# Out:
#           TrackP  TrackPt
# Ghost      0.809    1.586
# Electron   1.640    2.144
# Muon       1.140    0.812
# Pion       0.968    1.087
# Kaon       1.075    0.821
# Proton     1.028    0.992

# %% [markdown]
# ### Long Electron

# %% [markdown]
# <table>
# <tbody>
#
# <tr>
#
# <td width="50%">
# <img src= "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Electron/pic_new/png/Long_Electron-IDEff_V_OverallMisIDEff_Logy.png"/>
#
# The signal and background (Overal MissID) efficiencies are calculated for each of CombDLL and MVA Output cuts. The efficiency for the particular cut is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_cut}}{N_{total\_tracks}} * 100\% $$
# </td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Electron/pic_new/png/Long_Electron-PurityVMVAOut.png" />
#
# The purity of the signal tracks for the particular MVA Output cut value is calculated by the following expression:
#
# $$ Purity_{cut} = \frac{N_{signal\_tracks\_passed\_the\_cut}}{N_{all\_tracks\_passed\_the\_cut}} * 100\% $$
# $ $
#
# </td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Electron/pic_new/png/Long_Electron-MVAOutVBaselineMVA-Background_Logz.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Electron/pic_new/png/Long_Electron-MVAOutVBaselineMVA-Signal_Logz.png" /></td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Electron/pic_new/png/Long_ElectronMVAOut_Liny.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Electron/pic_new/png/Long_ElectronMVAOut_Logy.png" /></td>
#
# </tr>
#
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVTrackP_Long_Electron.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVTrackPt_Long_Electron.png" /></td>
#
# </tr>
#
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVNumProtoParticles_Long_Electron.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVPseudoRapidity_Long_Electron.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Each curve corresponds just one MVA Output cut value which provides particular overall MVA Efficiency value for a signal particle. Each point of the curves means the MVA Efficiency value for a signal particle in this particular Momentum/Transverse Momentum/NumProtParticles/Pseido Rapidity bin.
# </td>
# </tbody>
# </table>
#
# #### CvM tests:

# %%
flatness.loc[['Electron']]
# Out:
#           TrackP  TrackPt  P_Conf_level  Pt_Conf_level
# Electron   0.011    0.036         0.001          0.001

# %% [markdown]
# ### Long Kaon

# %% [markdown]
# <table>
# <tbody>
#
# <tr>
#
# <td width="50%">
# <img src= "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Kaon/pic_new/png/Long_Kaon-IDEff_V_OverallMisIDEff_Logy.png"/>
#
# The signal and background (Overal MissID) efficiencies are calculated for each of CombDLL and MVA Output cuts. The efficiency for the particular cut is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_cut}}{N_{total\_tracks}} * 100\% $$
# </td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Kaon/pic_new/png/Long_Kaon-PurityVMVAOut.png" />
#
# The purity of the signal tracks for the particular MVA Output cut value is calculated by the following expression:
#
# $$ Purity_{cut} = \frac{N_{signal\_tracks\_passed\_the\_cut}}{N_{all\_tracks\_passed\_the\_cut}} * 100\% $$
# $ $
#
# </td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Kaon/pic_new/png/Long_Kaon-MVAOutVBaselineMVA-Background_Logz.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Kaon/pic_new/png/Long_Kaon-MVAOutVBaselineMVA-Signal_Logz.png" /></td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Kaon/pic_new/png/Long_KaonMVAOut_Liny.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Kaon/pic_new/png/Long_KaonMVAOut_Logy.png" /></td>
#
# </tr>
#
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVTrackP_Long_Kaon.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVTrackPt_Long_Kaon.png" /></td>
#
# </tr>
#
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVNumProtoParticles_Long_Kaon.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVPseudoRapidity_Long_Kaon.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Each curve corresponds just one MVA Output cut value which provides particular overall MVA Efficiency value for a signal particle. Each point of the curves means the MVA Efficiency value for a signal particle in this particular Momentum/Transverse Momentum/NumProtParticles/Pseido Rapidity bin.
# </td>
# </tbody>
# </table>
#
# #### CvM tests:

# %%
flatness.loc[['Kaon']]
# Out:
#       TrackP  TrackPt  P_Conf_level  Pt_Conf_level
# Kaon   0.046     0.03         0.001          0.001

# %% [markdown]
# ### Long Muon

# %% [markdown]
# <table>
# <tbody>
#
# <tr>
#
# <td width="50%">
# <img src= "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Muon/pic_new/png/Long_Muon-IDEff_V_OverallMisIDEff_Logy.png"/>
#
# The signal and background (Overal MissID) efficiencies are calculated for each of CombDLL and MVA Output cuts. The efficiency for the particular cut is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_cut}}{N_{total\_tracks}} * 100\% $$
# </td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Muon/pic_new/png/Long_Muon-PurityVMVAOut.png" />
#
# The purity of the signal tracks for the particular MVA Output cut value is calculated by the following expression:
#
# $$ Purity_{cut} = \frac{N_{signal\_tracks\_passed\_the\_cut}}{N_{all\_tracks\_passed\_the\_cut}} * 100\% $$
# $ $
#
# </td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Muon/pic_new/png/Long_Muon-MVAOutVBaselineMVA-Background_Logz.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Muon/pic_new/png/Long_Muon-MVAOutVBaselineMVA-Signal_Logz.png" /></td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Muon/pic_new/png/Long_MuonMVAOut_Liny.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Muon/pic_new/png/Long_MuonMVAOut_Logy.png" /></td>
#
# </tr>
#
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVTrackP_Long_Muon.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVTrackPt_Long_Muon.png" /></td>
#
# </tr>
#
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVNumProtoParticles_Long_Muon.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVPseudoRapidity_Long_Muon.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Each curve corresponds just one MVA Output cut value which provides particular overall MVA Efficiency value for a signal particle. Each point of the curves means the MVA Efficiency value for a signal particle in this particular Momentum/Transverse Momentum/NumProtParticles/Pseido Rapidity bin.
# </td>
# </tbody>
# </table>
#
# #### CvM tests:

# %%
flatness.loc[['Muon']]
# Out:
#       TrackP  TrackPt  P_Conf_level  Pt_Conf_level
# Muon   0.023    0.037         0.001          0.001

# %% [markdown]
# ### Long Proton

# %% [markdown]
# <table>
# <tbody>
#
# <tr>
#
# <td width="50%">
# <img src= "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Proton/pic_new/png/Long_Proton-IDEff_V_OverallMisIDEff_Logy.png"/>
#
# The signal and background (Overal MissID) efficiencies are calculated for each of CombDLL and MVA Output cuts. The efficiency for the particular cut is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_cut}}{N_{total\_tracks}} * 100\% $$
# </td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Proton/pic_new/png/Long_Proton-PurityVMVAOut.png" />
#
# The purity of the signal tracks for the particular MVA Output cut value is calculated by the following expression:
#
# $$ Purity_{cut} = \frac{N_{signal\_tracks\_passed\_the\_cut}}{N_{all\_tracks\_passed\_the\_cut}} * 100\% $$
# $ $
#
# </td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Proton/pic_new/png/Long_Proton-MVAOutVBaselineMVA-Background_Logz.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Proton/pic_new/png/Long_Proton-MVAOutVBaselineMVA-Signal_Logz.png" /></td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Proton/pic_new/png/Long_ProtonMVAOut_Liny.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Proton/pic_new/png/Long_ProtonMVAOut_Logy.png" /></td>
#
# </tr>
#
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVTrackP_Long_Proton.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVTrackPt_Long_Proton.png" /></td>
#
# </tr>
#
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVNumProtoParticles_Long_Proton.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVPseudoRapidity_Long_Proton.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Each curve corresponds just one MVA Output cut value which provides particular overall MVA Efficiency value for a signal particle. Each point of the curves means the MVA Efficiency value for a signal particle in this particular Momentum/Transverse Momentum/NumProtParticles/Pseido Rapidity bin.
# </td>
# </tbody>
# </table>
#
# #### CvM tests:

# %%
flatness.loc[['Proton']]
# Out:
#         TrackP  TrackPt  P_Conf_level  Pt_Conf_level
# Proton   0.036    0.044         0.001          0.001

# %% [markdown]
# ## Long Pion
#
# <table>
# <tbody>
#
# <tr>
#
# <td width="50%">
# <img src= "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Pion/pic_new/png/Long_Pion-IDEff_V_OverallMisIDEff_Logy.png"/>
#
# The signal and background (Overal MissID) efficiencies are calculated for each of CombDLL and MVA Output cuts. The efficiency for the particular cut is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_cut}}{N_{total\_tracks}} * 100\% $$
# </td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Pion/pic_new/png/Long_Pion-PurityVMVAOut.png" />
#
# The purity of the signal tracks for the particular MVA Output cut value is calculated by the following expression:
#
# $$ Purity_{cut} = \frac{N_{signal\_tracks\_passed\_the\_cut}}{N_{all\_tracks\_passed\_the\_cut}} * 100\% $$
# $ $
#
# </td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Pion/pic_new/png/Long_Pion-MVAOutVBaselineMVA-Background_Logz.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Pion/pic_new/png/Long_Pion-MVAOutVBaselineMVA-Signal_Logz.png" /></td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Pion/pic_new/png/Long_PionMVAOut_Liny.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Pion/pic_new/png/Long_PionMVAOut_Logy.png" /></td>
#
# </tr>
#
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVTrackP_Long_Pion.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVTrackPt_Long_Pion.png" /></td>
#
# </tr>
#
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVNumProtoParticles_Long_Pion.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVPseudoRapidity_Long_Pion.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Each curve corresponds just one MVA Output cut value which provides particular overall MVA Efficiency value for a signal particle. Each point of the curves means the MVA Efficiency value for a signal particle in this particular Momentum/Transverse Momentum/NumProtParticles/Pseido Rapidity bin.
# </td>
# </tbody>
# </table>
#
# #### CvM tests:

# %%
flatness.loc[['Pion']]
# Out:
#       TrackP  TrackPt  P_Conf_level  Pt_Conf_level
# Pion   0.016    0.015         0.001          0.001

# %% [markdown]
# ### Long Ghost

# %% [markdown]
# <table>
# <tbody>
#
# <tr>
#
# <td width="50%">
# <img src= "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Ghost/pic_new/png/Long_Ghost-IDEff_V_OverallMisIDEff_Logy.png"/>
#
# The signal and background (Overal MissID) efficiencies are calculated for each of CombDLL and MVA Output cuts. The efficiency for the particular cut is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_cut}}{N_{total\_tracks}} * 100\% $$
# </td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Ghost/pic_new/png/Long_Ghost-PurityVMVAOut.png" />
#
# The purity of the signal tracks for the particular MVA Output cut value is calculated by the following expression:
#
# $$ Purity_{cut} = \frac{N_{signal\_tracks\_passed\_the\_cut}}{N_{all\_tracks\_passed\_the\_cut}} * 100\% $$
# $ $
#
# </td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Ghost/pic_new/png/Long_Ghost-MVAOutVBaselineMVA-Background_Logz.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Ghost/pic_new/png/Long_Ghost-MVAOutVBaselineMVA-Signal_Logz.png" /></td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Ghost/pic_new/png/Long_GhostMVAOut_Liny.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Ghost/pic_new/png/Long_GhostMVAOut_Logy.png" /></td>
#
# </tr>
#
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVTrackP_Long_Ghost.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVTrackPt_Long_Ghost.png" /></td>
#
# </tr>
#
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVNumProtoParticles_Long_Ghost.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/Keras/002/Flatness_SignalMVAEffVPseudoRapidity_Long_Ghost.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Each curve corresponds just one MVA Output cut value which provides particular overall MVA Efficiency value for a signal particle. Each point of the curves means the MVA Efficiency value for a signal particle in this particular Momentum/Transverse Momentum/NumProtParticles/Pseido Rapidity bin.
# </td>
# </tbody>
# </table>
#
# #### CvM tests:

# %%
flatness.loc[['Ghost']]
# Out:
#        TrackP  TrackPt  P_Conf_level  Pt_Conf_level
# Ghost   0.005    0.023         0.001          0.001
