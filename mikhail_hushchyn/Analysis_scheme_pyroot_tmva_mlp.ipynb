# %% [markdown]
# # LHCb Particle Identification

# %% [markdown]
# # Authors

# %% [markdown]
# Andrey Ustyuzhanin, YSDA, HSE <br>
# Denis Derkach, YSDA, HSE <br>
# Tatiana Likhomanenko, YSDA, HSE <br>
# Mikhail Hushchyn, YSDA, MIPT <br>
# Eltyshev Evgenii, YSDA, MIPT <br>
# Sergei Korolev, YSDA, HSE <br>
# Dmitry Petrov, YSDA, HSE <br>

# %% [markdown]
# # Baseline

# %% [markdown]
# For the baseline repeating the following configuration was choosen:
#
# *Train config:* TrainPhysTks-EvalPhysTks-NoReweight <br>
# *Net config:* TMVA-Run2-NoTkLikCDVelodEdx <br>
# *GhostAccFrac:* 1.0 <br>
# *Training data:* Mixture <br>
# *Data files:* MC2015Sim09Dev03 <br>

# %% [markdown]
# ## TMVA MLP

# %% [markdown]
# A list of the classifier's parameters is shown below:
#
# *Method:* kMLP <br>
# *Factory_options:* V:!Silent:!Color:!DrawProgressBar:Transformations=I <br>
# *H:* true <br>
# *V:* true <br>
# *EpochMonitoring:* true <br>
# *HiddenLayers:* 1.4 x len(features) <br>
# *UseRegulator:* true <br>
# *ConvergenceImprove:* 1e-16 <br>
# *ConvergenceTests:* 15 <br>
# *VarTransform:* Norm <br>
# *NCycles:* 750 <br>
# *NeuronType:* sigmoid <br>
# *TrainingMethod:* BP <br>
# *EstimatorType:* CE <br>

# %% [markdown]
# ## Overall quality

# %% [markdown]
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/overall_roc_auc.png" /> <br>
#
#
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/class_vs_class_roc_auc_matrix.png" />
#
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/Ghost_vs_one_roc_auc.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/Electron_vs_one_roc_auc.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/Muon_vs_one_roc_auc.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/Pion_vs_one_roc_auc.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/Kaon_vs_one_roc_auc.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/Proton_vs_one_roc_auc.png" /></td>
#
# </tr>
# </tbody>
# </table>

# %%
import pandas
pandas.set_option('display.precision',4)
matrix = pandas.read_csv("baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/\
GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/class_vs_class_roc_auc_matrix.csv", index_col=0)
particles = ['Electron', 'Proton', 'Pion', 'Muon', 'Kaon', 'Ghost']
matrix
# Out:
#           Electron  Proton    Pion    Muon    Kaon   Ghost
# Electron    1.0000  0.9854  0.9778  0.9964  0.9849  0.9538
# Proton      0.9854  1.0000  0.9542  0.9945  0.7872  0.9747
# Pion        0.9775  0.9542  1.0000  0.9876  0.9549  0.9607
# Muon        0.9964  0.9945  0.9876  1.0000  0.9934  0.9920
# Kaon        0.9849  0.7872  0.9549  0.9934  1.0000  0.9772
# Ghost       0.9538  0.9747  0.9607  0.9920  0.9772  1.0000

# %% [markdown]
# # Cramer–von Mises test
#
# We use Cramer–von Mises (CvM) test to measure correlation between MVA Output and momentum/transverse momentum for signal particle.
#
# The correlation between MVA Output and momentum/transverse momentum for a signal particle is absent with confidence of 95 % if the CvM value for the particle less than appropriate CvM confidence value. The confidence values for the each particle are presented in the table below.
#
# For computing CvM metric the global predictions CDF is compared to
# a local (in some momentum/transverse momentum interval) predictions CDF. After that all intervals are
# averaged:
#
# $$
# CvM_{\text{interval}} = \int (F_{\text{global}} - F_{\text{interval}})^2 \, d\, F_{global}
# $$
# <br>
# $$
# CvM = <CvM_{\text{interval}}>_{\text{interval}}
# $$
#
# where $F_{global}$, $F_{\text{interval}}$ are predictions cumulative distribution functions
# for all data and data in some momentum/transverse momentum interval corresponding
#
# ### References:
# 1. https://kaggle2.blob.core.windows.net/competitions/kaggle/4488/media/lhcb_description_official.pdf , p.8
# 2. https://en.wikipedia.org/wiki/Cramér–von_Mises_criterion
# 3. https://indico.cern.ch/event/433556/session/1/contribution/7/attachments/1230891/1804264/Rogozhnikov_boosting_in_HEP.pdf p.25-26

# %% [markdown]
# ### CvM tests and 95% confidence values for signal particles

# %%
flatness = pandas.read_csv("baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/\
GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/flatness.csv")
#pandas.set_option('display.precision',3)
cols = ['Particle', 'TrackP', 'P_Conf_level', 'TrackPt', 'Pt_Conf_level']
flatness[cols[1:]] = flatness[cols[1:]].round(3)
flatness[cols]
# Out:
#    Particle  TrackP  P_Conf_level  TrackPt  Pt_Conf_level
# 0  Electron   0.007         0.001    0.017          0.001
# 1    Proton   0.035         0.001    0.045          0.001
# 2      Pion   0.017         0.001    0.014          0.001
# 3      Muon   0.020         0.001    0.045          0.001
# 4      Kaon   0.043         0.001    0.037          0.001
# 5     Ghost   0.007         0.001    0.014          0.001

# %% [markdown]
# ### Long Electron

# %% [markdown]
# <table>
# <tbody>
#
# <tr>
#
# <td width="50%">
# <img src= "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/pic/png/Long_Electron-IDEff_V_OverallMisIDEff_Logy.png"/>
#
# The signal and background (Overal MissID) efficiencies are calculated for each of CombDLL and MVA Output cuts. The efficiency for the particular cut is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_cut}}{N_{total\_tracks}} * 100\% $$
# </td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/pic/png/Long_Electron-PurityVMVAOut.png" />
#
# The purity of the signal tracks for the particular MVA Output cut value is calculated by the following expression:
#
# $$ Purity_{cut} = \frac{N_{signal\_tracks\_passed\_the\_cut}}{N_{all\_tracks\_passed\_the\_cut}} * 100\% $$
# $ $
#
# </td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/pic/png/Long_Electron-MVAOutVDLL-Background_Logz.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/pic/png/Long_Electron-MVAOutVDLL-Signal_Logz.png" /></td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/pic/png/Long_ElectronMVAOut_Liny.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/pic/png/Long_ElectronMVAOut_Logy.png" /></td>
#
# </tr>
#
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Electron-MVAEff-DLLCut-8.000.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Electron-MVAEff-DLLCut-2.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Electron-MVAEff-DLLCut2.000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Electron-MVAEff-DLLCut8.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td colspan=2 align='center'>
# Efficiency for the each MVA Output and CombDLL cut values is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_MVA\_\_and\_CombDLL\_cuts}}{N_{total\_tracks\_passed\_the\_CombDLL\_cut}} * 100\% $$
#
# Each ghaph above corresponds one CombDLL cut value.
#
# </td>
#
#
# </tr>
# </tbody>
# </table>
#
# __________
#
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Electron-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Electron-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Electron-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Electron-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each momentum bin separately. Efficiency in particular momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
#
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Electron-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Electron-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Electron-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Electron-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each transverse momentum bin separately. Efficiency in particular transverse momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/Flatness_SignalMVAEffVTrackP_Long_Electron.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/PyROOT_TMVA/kMLP/Flatness_SignalMVAEffVTrackPt_Long_Electron.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Each curve corresponds just one MVA Output cut value which provides particular overall MVA Efficiency value for a signal particle. Each point of the curves means the MVA Efficiency value for a signal particle in this particular Momentum/Transverse Momentum bin.
# </td>
# </tbody>
# </table>
#
# #### CvM tests:

# %%
flatness[flatness.Particle == 'Electron'][cols]
# Out:
#    Particle  TrackP  P_Conf_level  TrackPt  Pt_Conf_level
# 0  Electron   0.007         0.001    0.017          0.001

# %% [markdown]
# ### Long Kaon

# %% [markdown]
# <table>
# <tbody>
#
# <tr>
#
# <td width="50%">
# <img src= "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/pic/png/Long_Kaon-IDEff_V_OverallMisIDEff_Logy.png"/>
#
# The signal and background (Overal MissID) efficiencies are calculated for each of CombDLL and MVA Output cuts. The efficiency for the particular cut is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_cut}}{N_{total\_tracks}} * 100\% $$
# </td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/pic/png/Long_Kaon-PurityVMVAOut.png" />
#
# The purity of the signal tracks for the particular MVA Output cut value is calculated by the following expression:
#
# $$ Purity_{cut} = \frac{N_{signal\_tracks\_passed\_the\_cut}}{N_{all\_tracks\_passed\_the\_cut}} * 100\% $$
# $ $
#
# </td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/pic/png/Long_Kaon-MVAOutVDLL-Background_Logz.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/pic/png/Long_Kaon-MVAOutVDLL-Signal_Logz.png" /></td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/pic/png/Long_KaonMVAOut_Liny.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/pic/png/Long_KaonMVAOut_Logy.png" /></td>
#
# </tr>
#
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Kaon-MVAEff-DLLCut-8.000.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Kaon-MVAEff-DLLCut-2.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Kaon-MVAEff-DLLCut2.000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Kaon-MVAEff-DLLCut8.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td colspan=2 align='center'>
# Efficiency for the each MVA Output and CombDLL cut values is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_MVA\_\_and\_CombDLL\_cuts}}{N_{total\_tracks\_passed\_the\_CombDLL\_cut}} * 100\% $$
#
# Each ghaph above corresponds one CombDLL cut value.
#
# </td>
#
#
# </tr>
# </tbody>
# </table>
#
# __________
#
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Kaon-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Kaon-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Kaon-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Kaon-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each momentum bin separately. Efficiency in particular momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
#
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Kaon-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Kaon-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Kaon-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Kaon-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each transverse momentum bin separately. Efficiency in particular transverse momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/Flatness_SignalMVAEffVTrackP_Long_Kaon.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/PyROOT_TMVA/kMLP/Flatness_SignalMVAEffVTrackPt_Long_Kaon.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Each curve corresponds just one MVA Output cut value which provides particular overall MVA Efficiency value for a signal particle. Each point of the curves means the MVA Efficiency value for a signal particle in this particular Momentum/Transverse Momentum bin.
# </td>
# </tbody>
# </table>
#
# #### CvM tests:

# %%
flatness[flatness.Particle == 'Kaon'][cols]
# Out:
#   Particle  TrackP  P_Conf_level  TrackPt  Pt_Conf_level
# 4     Kaon   0.043         0.001    0.037          0.001

# %% [markdown]
# ### Long Muon

# %% [markdown]
# <table>
# <tbody>
#
# <tr>
#
# <td width="50%">
# <img src= "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/pic/png/Long_Muon-IDEff_V_OverallMisIDEff_Logy.png"/>
#
# The signal and background (Overal MissID) efficiencies are calculated for each of CombDLL and MVA Output cuts. The efficiency for the particular cut is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_cut}}{N_{total\_tracks}} * 100\% $$
# </td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/pic/png/Long_Muon-PurityVMVAOut.png" />
#
# The purity of the signal tracks for the particular MVA Output cut value is calculated by the following expression:
#
# $$ Purity_{cut} = \frac{N_{signal\_tracks\_passed\_the\_cut}}{N_{all\_tracks\_passed\_the\_cut}} * 100\% $$
# $ $
#
# </td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/pic/png/Long_Muon-MVAOutVDLL-Background_Logz.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/pic/png/Long_Muon-MVAOutVDLL-Signal_Logz.png" /></td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/pic/png/Long_MuonMVAOut_Liny.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/pic/png/Long_MuonMVAOut_Logy.png" /></td>
#
# </tr>
#
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Muon-MVAEff-DLLCut-8.000.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Muon-MVAEff-DLLCut-2.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Muon-MVAEff-DLLCut2.000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Muon-MVAEff-DLLCut8.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td colspan=2 align='center'>
# Efficiency for the each MVA Output and CombDLL cut values is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_MVA\_\_and\_CombDLL\_cuts}}{N_{total\_tracks\_passed\_the\_CombDLL\_cut}} * 100\% $$
#
# Each ghaph above corresponds one CombDLL cut value.
#
# </td>
#
#
# </tr>
# </tbody>
# </table>
#
# __________
#
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Muon-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Muon-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Muon-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Muon-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each momentum bin separately. Efficiency in particular momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
#
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Muon-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Muon-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Muon-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Muon-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each transverse momentum bin separately. Efficiency in particular transverse momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/Flatness_SignalMVAEffVTrackP_Long_Muon.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/PyROOT_TMVA/kMLP/Flatness_SignalMVAEffVTrackPt_Long_Muon.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Each curve corresponds just one MVA Output cut value which provides particular overall MVA Efficiency value for a signal particle. Each point of the curves means the MVA Efficiency value for a signal particle in this particular Momentum/Transverse Momentum bin.
# </td>
# </tbody>
# </table>
#
# #### CvM tests:

# %%
flatness[flatness.Particle == 'Muon'][cols]
# Out:
#   Particle  TrackP  P_Conf_level  TrackPt  Pt_Conf_level
# 3     Muon    0.02         0.001    0.045          0.001

# %% [markdown]
# ### Long Proton

# %% [markdown]
# <table>
# <tbody>
#
# <tr>
#
# <td width="50%">
# <img src= "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/pic/png/Long_Proton-IDEff_V_OverallMisIDEff_Logy.png"/>
#
# The signal and background (Overal MissID) efficiencies are calculated for each of CombDLL and MVA Output cuts. The efficiency for the particular cut is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_cut}}{N_{total\_tracks}} * 100\% $$
# </td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/pic/png/Long_Proton-PurityVMVAOut.png" />
#
# The purity of the signal tracks for the particular MVA Output cut value is calculated by the following expression:
#
# $$ Purity_{cut} = \frac{N_{signal\_tracks\_passed\_the\_cut}}{N_{all\_tracks\_passed\_the\_cut}} * 100\% $$
# $ $
#
# </td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/pic/png/Long_Proton-MVAOutVDLL-Background_Logz.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/pic/png/Long_Proton-MVAOutVDLL-Signal_Logz.png" /></td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/pic/png/Long_ProtonMVAOut_Liny.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/pic/png/Long_ProtonMVAOut_Logy.png" /></td>
#
# </tr>
#
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Proton-MVAEff-DLLCut-8.000.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Proton-MVAEff-DLLCut-2.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Proton-MVAEff-DLLCut2.000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Proton-MVAEff-DLLCut8.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td colspan=2 align='center'>
# Efficiency for the each MVA Output and CombDLL cut values is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_MVA\_\_and\_CombDLL\_cuts}}{N_{total\_tracks\_passed\_the\_CombDLL\_cut}} * 100\% $$
#
# Each ghaph above corresponds one CombDLL cut value.
#
# </td>
#
#
# </tr>
# </tbody>
# </table>
#
# __________
#
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Proton-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Proton-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Proton-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Proton-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each momentum bin separately. Efficiency in particular momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
#
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Proton-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Proton-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Proton-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Proton-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each transverse momentum bin separately. Efficiency in particular transverse momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/Flatness_SignalMVAEffVTrackP_Long_Proton.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/PyROOT_TMVA/kMLP/Flatness_SignalMVAEffVTrackPt_Long_Proton.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Each curve corresponds just one MVA Output cut value which provides particular overall MVA Efficiency value for a signal particle. Each point of the curves means the MVA Efficiency value for a signal particle in this particular Momentum/Transverse Momentum bin.
# </td>
# </tbody>
# </table>
#
# #### CvM tests:

# %%
flatness[flatness.Particle == 'Proton'][cols]
# Out:
#   Particle  TrackP  P_Conf_level  TrackPt  Pt_Conf_level
# 1   Proton   0.035         0.001    0.045          0.001

# %% [markdown]
# ### Long Pion
# <table>
# <tbody>
#
# <tr>
#
# <td width="50%">
# <img src= "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/pic/png/Long_Pion-IDEff_V_OverallMisIDEff_Logy.png"/>
#
# The signal and background (Overal MissID) efficiencies are calculated for each of CombDLL and MVA Output cuts. The efficiency for the particular cut is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_cut}}{N_{total\_tracks}} * 100\% $$
# </td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/pic/png/Long_Pion-PurityVMVAOut.png" />
#
# The purity of the signal tracks for the particular MVA Output cut value is calculated by the following expression:
#
# $$ Purity_{cut} = \frac{N_{signal\_tracks\_passed\_the\_cut}}{N_{all\_tracks\_passed\_the\_cut}} * 100\% $$
# $ $
#
# </td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/pic/png/Long_Pion-MVAOutVDLL-Background_Logz.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/pic/png/Long_Pion-MVAOutVDLL-Signal_Logz.png" /></td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/pic/png/Long_PionMVAOut_Liny.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/pic/png/Long_PionMVAOut_Logy.png" /></td>
#
# </tr>
#
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Pion-MVAEff-DLLCut-8.000.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Pion-MVAEff-DLLCut-2.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Pion-MVAEff-DLLCut2.000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Pion-MVAEff-DLLCut8.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td colspan=2 align='center'>
# Efficiency for the each MVA Output and CombDLL cut values is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_MVA\_\_and\_CombDLL\_cuts}}{N_{total\_tracks\_passed\_the\_CombDLL\_cut}} * 100\% $$
#
# Each ghaph above corresponds one CombDLL cut value.
#
# </td>
#
#
# </tr>
# </tbody>
# </table>
#
# __________
#
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Pion-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Pion-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Pion-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Pion-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each momentum bin separately. Efficiency in particular momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
#
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Pion-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Pion-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Pion-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Pion-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each transverse momentum bin separately. Efficiency in particular transverse momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/Flatness_SignalMVAEffVTrackP_Long_Pion.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/PyROOT_TMVA/kMLP/Flatness_SignalMVAEffVTrackPt_Long_Pion.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Each curve corresponds just one MVA Output cut value which provides particular overall MVA Efficiency value for a signal particle. Each point of the curves means the MVA Efficiency value for a signal particle in this particular Momentum/Transverse Momentum bin.
# </td>
# </tbody>
# </table>
#
# #### CvM tests:

# %%
flatness[flatness.Particle == 'Pion'][cols]
# Out:
#   Particle  TrackP  P_Conf_level  TrackPt  Pt_Conf_level
# 2     Pion   0.017         0.001    0.014          0.001

# %% [markdown]
# ### Long Ghost

# %% [markdown]
# <table>
# <tbody>
#
# <tr>
#
# <td width="50%">
# <img src= "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/pic/png/Long_Ghost-IDEff_V_OverallMisIDEff_Logy.png"/>
#
# The signal and background (Overal MissID) efficiencies are calculated for each of CombDLL and MVA Output cuts. The efficiency for the particular cut is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_cut}}{N_{total\_tracks}} * 100\% $$
# </td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/pic/png/Long_Ghost-PurityVMVAOut.png" />
#
# The purity of the signal tracks for the particular MVA Output cut value is calculated by the following expression:
#
# $$ Purity_{cut} = \frac{N_{signal\_tracks\_passed\_the\_cut}}{N_{all\_tracks\_passed\_the\_cut}} * 100\% $$
# $ $
#
# </td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/pic/png/Long_Ghost-MVAOutVDLL-Background_Logz.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/pic/png/Long_Ghost-MVAOutVDLL-Signal_Logz.png" /></td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/pic/png/Long_GhostMVAOut_Liny.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/pic/png/Long_GhostMVAOut_Logy.png" /></td>
#
# </tr>
#
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Ghost-MVAEff-DLLCut-8.000.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Ghost-MVAEff-DLLCut-2.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Ghost-MVAEff-DLLCut2.000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Ghost-MVAEff-DLLCut8.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td colspan=2 align='center'>
# Efficiency for the each MVA Output and CombDLL cut values is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_MVA\_\_and\_CombDLL\_cuts}}{N_{total\_tracks\_passed\_the\_CombDLL\_cut}} * 100\% $$
#
# Each ghaph above corresponds one CombDLL cut value.
#
# </td>
#
#
# </tr>
# </tbody>
# </table>
#
# __________
#
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Ghost-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Ghost-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Ghost-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Ghost-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each momentum bin separately. Efficiency in particular momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
#
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Ghost-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Ghost-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Ghost-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Ghost-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each transverse momentum bin separately. Efficiency in particular transverse momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/Flatness_SignalMVAEffVTrackP_Long_Ghost.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/PyROOT_TMVA/kMLP/Flatness_SignalMVAEffVTrackPt_Long_Ghost.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Each curve corresponds just one MVA Output cut value which provides particular overall MVA Efficiency value for a signal particle. Each point of the curves means the MVA Efficiency value for a signal particle in this particular Momentum/Transverse Momentum bin.
# </td>
# </tbody>
# </table>
#
# #### CvM tests:

# %%
flatness[flatness.Particle == 'Ghost'][cols]
# Out:
#   Particle  TrackP  P_Conf_level  TrackPt  Pt_Conf_level
# 5    Ghost   0.007         0.001    0.014          0.001
