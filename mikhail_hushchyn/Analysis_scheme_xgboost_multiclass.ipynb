# %% [markdown]
# # LHCb Particle Identification

# %% [markdown]
# # Authors

# %% [markdown]
# Andrey Ustyuzhanin, YSDA, HSE <br>
# Denis Derkach, YSDA, HSE <br>
# Tatiana Likhomanenko, YSDA, HSE <br>
# Mikhail Hushchyn, YSDA, MIPT <br>
# Eltyshev Evgenii, YSDA, MIPT <br>
# Sergei Korolev, YSDA, HSE <br>
# Dmitry Petrov, YSDA, HSE <br>

# %% [markdown]
# # Multiclass XGBoost

# %% [markdown]
# For the baseline repeating the following configuration was choosen:
#
# *Train config:* TrainPhysTks-EvalPhysTks-NoReweight <br>
# *Net config:* TMVA-Run2-NoTkLikCDVelodEdx <br>
# *GhostAccFrac:* 1.0 <br>
# *Training data:* Mixture <br>
# *Data files:* MC2015Sim09Dev03 <br>

# %% [markdown]
# ## XGBoost

# %% [markdown]
# Data was balanced
#
# A list of the classifier's parameters is shown below:
#
# *features:*  <br>
# ['BremPIDe',
#   'CaloPrsE',
#   'EcalPIDe',
#   'EcalPIDmu',
#   'HcalPIDe',
#   'HcalPIDmu',
#   'InAccBrem',
#   'InAccEcal',
#   'InAccHcal',
#   'InAccMuon',
#   'InAccPrs',
#   'MuonBkgLL',
#   'MuonIsLooseMuon',
#   'MuonIsMuon',
#   'MuonMuLL',
#   'MuonNShared',
#   'PrsPIDe',
#   'RichAboveKaThres',
#   'RichAboveMuThres',
#   'RichAbovePiThres',
#   'RichAbovePrThres',
#   'RichDLLbt',
#   'RichDLLe',
#   'RichDLLk',
#   'RichDLLmu',
#   'RichDLLp',
#   'RichUsedR1Gas',
#   'RichUsedR2Gas',
#   'TrackChi2PerDof',
#   'TrackFitMatchChi2',
#   'TrackFitTChi2',
#   'TrackFitTNDoF',
#   'TrackFitVeloChi2',
#   'TrackFitVeloNDoF',
#   'TrackGhostProbability',
#   'TrackNumDof',
#   'TrackP',
#   'TrackPt'] <br>
#    <br>
# *base_score:* 0.5 <br>
# *colsample:* 0.7 <br>
# *eta:* 0.01 <br>
# *gamma:* None <br>
# *max_depth:* 8 <br>
# *min_child_weight:* 50.0 <br>
# *missing:* -999.0 <br>
# *n_estimators:* 1000 <br>
# *nthreads:* 4 <br>
# *num_feature:* None <br>
# *random_state:* 0 <br>
# *scale_pos_weight:* 1.0 <br>
# *subsample:* 0.5 <br>
# *verbose:* 0 <br>
#
# **IPython notebook:** [notebook](https://github.com/yandexdataschool/PID/blob/f0c9c6fb222e8bb0206eed00cddfbef16f44875a/mikhail_hushchyn/xgboost-multiclass.ipynb)
#
# **Directory with model and figures:** [directory](https://github.com/yandexdataschool/PID/tree/master/mikhail_hushchyn/baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose%3D0%3Bmissing%3D-999.0%3Bscale_pos_weight%3D1.0%3Brandom_state%3D0%3Bnum_feature%3DNone%3Bbase_score%3D0.5%3Bn_estimators%3D1000%3Bsubsample%3D0.5%3Beta%3D0.01%3Bmin_child_weight%3D50%3Bcolsample%3D0.7%3Bmax_depth%3D8%3Bgamma%3DNone%3Bnthreads%3D4%3Bbalanced_data_235449)

# %% [markdown]
# ## Overall quality

# %%
import numpy
work_path = "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/\
multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;\
base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;\
gamma=None;nthreads=4;balanced_data_235449/"
logloss = numpy.loadtxt(work_path + '/logloss_eval.csv')
print "Log loss is ", logloss
# Out:
# Log loss is  0.670207105743

# %% [markdown]
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/overall_roc_auc.png" /> <br>
#
#
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/class_vs_class_roc_auc_matrix.png" />
#
#
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Ghost_vs_one_roc_auc.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Electron_vs_one_roc_auc.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Muon_vs_one_roc_auc.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Pion_vs_one_roc_auc.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Kaon_vs_one_roc_auc.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Proton_vs_one_roc_auc.png" /></td>
#
# </tr>
# </tbody>
# </table>

# %%
import pandas
pandas.set_option('display.precision',3)
matrix = pandas.read_csv(work_path + "class_vs_class_roc_auc_matrix.csv", index_col=0)
particles = ['Electron', 'Proton', 'Pion', 'Muon', 'Kaon', 'Ghost']
matrix
# Out:
#           Ghost  Electron   Muon   Pion   Kaon  Proton
# Ghost     1.000     0.971  0.996  0.966  0.982   0.980
# Electron  0.971     1.000  0.999  0.995  0.997   0.997
# Muon      0.996     0.999  1.000  0.992  0.996   0.997
# Pion      0.966     0.995  0.992  1.000  0.958   0.957
# Kaon      0.982     0.997  0.996  0.958  1.000   0.792
# Proton    0.980     0.997  0.997  0.957  0.792   1.000

# %% [markdown]
# # The quality with respect to the baseline
#
# $$
# Ratio = \frac{Roc\_Auc\_of\_this\_solution}{Roc\_Auc\_of\_the\_baseline}
# $$

# %% [markdown]
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/class_vs_class_roc_auc_rel_matrix.png" />

# %%
import pandas
pandas.set_option('display.precision',3)
rel_matrix = pandas.read_csv(work_path + "class_vs_class_roc_auc_rel_matrix.csv", index_col=0)
rel_matrix
# Out:
#           Ghost  Electron   Muon   Pion   Kaon  Proton
# Ghost     1.000     1.018  1.004  1.006  1.005   1.005
# Electron  1.018     1.000  1.003  1.018  1.012   1.011
# Muon      1.004     1.003  1.000  1.005  1.003   1.003
# Pion      1.006     1.017  1.005  1.000  1.003   1.003
# Kaon      1.005     1.012  1.003  1.003  1.000   1.006
# Proton    1.005     1.011  1.003  1.003  1.006   1.000

# %% [markdown]
# # Cramer–von Mises test
#
# We use Cramer–von Mises (CvM) test to measure correlation between MVA Output and momentum/transverse momentum for signal particle.
#
# The correlation between MVA Output and momentum/transverse momentum for a signal particle is absent with confidence of 95 % if the CvM value for the particle less than appropriate CvM confidence value. The confidence values for the each particle are presented in the table below.
#
# For computing CvM metric the global predictions CDF is compared to
# a local (in some momentum/transverse momentum interval) predictions CDF. After that all intervals are
# averaged:
#
# $$
# CvM_{\text{interval}} = \int (F_{\text{global}} - F_{\text{interval}})^2 \, d\, F_{global}
# $$
# <br>
# $$
# CvM = <CvM_{\text{interval}}>_{\text{interval}}
# $$
#
# where $F_{global}$, $F_{\text{interval}}$ are predictions cumulative distribution functions
# for all data and data in some momentum/transverse momentum interval corresponding
#
# ### References:
# 1. https://kaggle2.blob.core.windows.net/competitions/kaggle/4488/media/lhcb_description_official.pdf , p.8
# 2. https://en.wikipedia.org/wiki/Cramér–von_Mises_criterion
# 3. https://indico.cern.ch/event/433556/session/1/contribution/7/attachments/1230891/1804264/Rogozhnikov_boosting_in_HEP.pdf p.25-26

# %% [markdown]
# ### CvM tests and 95% confidence values for signal particles

# %%
flatness = pandas.read_csv(work_path + "flatness.csv", index_col=0)
#pandas.set_option('display.precision',3)
cols = ['TrackP', 'P_Conf_level', 'TrackPt', 'Pt_Conf_level']
flatness[cols] = flatness[cols].round(3)
flatness
# Out:
#           TrackP  TrackPt  P_Conf_level  Pt_Conf_level
# Ghost      0.004    0.013         0.001          0.001
# Electron   0.008    0.031         0.001          0.001
# Muon       0.031    0.043         0.001          0.001
# Pion       0.018    0.015         0.001          0.001
# Kaon       0.048    0.033         0.001          0.001
# Proton     0.038    0.046         0.001          0.001

# %% [markdown]
# # The CvM tests with respect to the baseline
#
# $$
# Ratio = \frac{CvM\_tests\_for\_this\_solution}{CvM\_tests\_for\_the\_baseline}
# $$

# %%
rel_flatness = pandas.read_csv(work_path + "rel_flatness.csv", index_col=0)
#pandas.set_option('display.precision',3)
rel_cols = ['TrackP', 'TrackPt']
rel_flatness = rel_flatness.round(3)
rel_flatness
# Out:
#           TrackP  TrackPt
# Ghost      0.677    0.935
# Electron   1.247    1.876
# Muon       1.507    0.954
# Pion       1.089    1.089
# Kaon       1.115    0.910
# Proton     1.097    1.032

# %% [markdown]
# ### Long Electron

# %% [markdown]
# <table>
# <tbody>
#
# <tr>
#
# <td width="50%">
# <img src= "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Electron/pic/png/Long_Electron-IDEff_V_OverallMisIDEff_Logy.png"/>
#
# The signal and background (Overal MissID) efficiencies are calculated for each of CombDLL and MVA Output cuts. The efficiency for the particular cut is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_cut}}{N_{total\_tracks}} * 100\% $$
# </td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Electron/pic/png/Long_Electron-PurityVMVAOut.png" />
#
# The purity of the signal tracks for the particular MVA Output cut value is calculated by the following expression:
#
# $$ Purity_{cut} = \frac{N_{signal\_tracks\_passed\_the\_cut}}{N_{all\_tracks\_passed\_the\_cut}} * 100\% $$
# $ $
#
# </td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Electron/pic/png/Long_Electron-MVAOutVDLL-Background_Logz.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Electron/pic/png/Long_Electron-MVAOutVDLL-Signal_Logz.png" /></td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Electron/pic/png/Long_ElectronMVAOut_Liny.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Electron/pic/png/Long_ElectronMVAOut_Logy.png" /></td>
#
# </tr>
#
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Electron/pic/png/MVAEffForDLLCut/Long_Electron-MVAEff-DLLCut-8.000.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Electron/pic/png/MVAEffForDLLCut/Long_Electron-MVAEff-DLLCut-2.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Electron/pic/png/MVAEffForDLLCut/Long_Electron-MVAEff-DLLCut2.000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Electron/pic/png/MVAEffForDLLCut/Long_Electron-MVAEff-DLLCut8.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td colspan=2 align='center'>
# Efficiency for the each MVA Output and CombDLL cut values is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_MVA\_\_and\_CombDLL\_cuts}}{N_{total\_tracks\_passed\_the\_CombDLL\_cut}} * 100\% $$
#
# Each ghaph above corresponds one CombDLL cut value.
#
# </td>
#
#
# </tr>
# </tbody>
# </table>
#
# __________
#
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Electron/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Electron-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Electron/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Electron-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Electron/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Electron-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Electron/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Electron-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each momentum bin separately. Efficiency in particular momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
#
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Electron/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Electron-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Electron/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Electron-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Electron/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Electron-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Electron/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Electron-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each transverse momentum bin separately. Efficiency in particular transverse momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Flatness_SignalMVAEffVTrackP_Long_Electron.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Flatness_SignalMVAEffVTrackPt_Long_Electron.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Each curve corresponds just one MVA Output cut value which provides particular overall MVA Efficiency value for a signal particle. Each point of the curves means the MVA Efficiency value for a signal particle in this particular Momentum/Transverse Momentum bin.
# </td>
# </tbody>
# </table>
#
# #### CvM tests:

# %%
flatness.loc[['Electron']]
# Out:
#           TrackP  TrackPt  P_Conf_level  Pt_Conf_level
# Electron   0.008    0.031         0.001          0.001

# %% [markdown]
# ### Long Kaon

# %% [markdown]
# <table>
# <tbody>
#
# <tr>
#
# <td width="50%">
# <img src= "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Kaon/pic/png/Long_Kaon-IDEff_V_OverallMisIDEff_Logy.png"/>
#
# The signal and background (Overal MissID) efficiencies are calculated for each of CombDLL and MVA Output cuts. The efficiency for the particular cut is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_cut}}{N_{total\_tracks}} * 100\% $$
# </td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Kaon/pic/png/Long_Kaon-PurityVMVAOut.png" />
#
# The purity of the signal tracks for the particular MVA Output cut value is calculated by the following expression:
#
# $$ Purity_{cut} = \frac{N_{signal\_tracks\_passed\_the\_cut}}{N_{all\_tracks\_passed\_the\_cut}} * 100\% $$
# $ $
#
# </td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Kaon/pic/png/Long_Kaon-MVAOutVDLL-Background_Logz.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Kaon/pic/png/Long_Kaon-MVAOutVDLL-Signal_Logz.png" /></td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Kaon/pic/png/Long_KaonMVAOut_Liny.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Kaon/pic/png/Long_KaonMVAOut_Logy.png" /></td>
#
# </tr>
#
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Kaon/pic/png/MVAEffForDLLCut/Long_Kaon-MVAEff-DLLCut-8.000.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Kaon/pic/png/MVAEffForDLLCut/Long_Kaon-MVAEff-DLLCut-2.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Kaon/pic/png/MVAEffForDLLCut/Long_Kaon-MVAEff-DLLCut2.000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Kaon/pic/png/MVAEffForDLLCut/Long_Kaon-MVAEff-DLLCut8.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td colspan=2 align='center'>
# Efficiency for the each MVA Output and CombDLL cut values is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_MVA\_\_and\_CombDLL\_cuts}}{N_{total\_tracks\_passed\_the\_CombDLL\_cut}} * 100\% $$
#
# Each ghaph above corresponds one CombDLL cut value.
#
# </td>
#
#
# </tr>
# </tbody>
# </table>
#
# __________
#
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Kaon/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Kaon-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Kaon/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Kaon-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Kaon/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Kaon-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Kaon/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Kaon-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each momentum bin separately. Efficiency in particular momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
#
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Kaon/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Kaon-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Kaon/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Kaon-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Kaon/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Kaon-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Kaon/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Kaon-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each transverse momentum bin separately. Efficiency in particular transverse momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Flatness_SignalMVAEffVTrackP_Long_Kaon.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Flatness_SignalMVAEffVTrackPt_Long_Kaon.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Each curve corresponds just one MVA Output cut value which provides particular overall MVA Efficiency value for a signal particle. Each point of the curves means the MVA Efficiency value for a signal particle in this particular Momentum/Transverse Momentum bin.
# </td>
# </tbody>
# </table>
#
# #### CvM tests:

# %%
flatness.loc[['Kaon']]
# Out:
#       TrackP  TrackPt  P_Conf_level  Pt_Conf_level
# Kaon   0.048    0.033         0.001          0.001

# %% [markdown]
# ### Long Muon

# %% [markdown]
# <table>
# <tbody>
#
# <tr>
#
# <td width="50%">
# <img src= "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Muon/pic/png/Long_Muon-IDEff_V_OverallMisIDEff_Logy.png"/>
#
# The signal and background (Overal MissID) efficiencies are calculated for each of CombDLL and MVA Output cuts. The efficiency for the particular cut is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_cut}}{N_{total\_tracks}} * 100\% $$
# </td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Muon/pic/png/Long_Muon-PurityVMVAOut.png" />
#
# The purity of the signal tracks for the particular MVA Output cut value is calculated by the following expression:
#
# $$ Purity_{cut} = \frac{N_{signal\_tracks\_passed\_the\_cut}}{N_{all\_tracks\_passed\_the\_cut}} * 100\% $$
# $ $
#
# </td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Muon/pic/png/Long_Muon-MVAOutVDLL-Background_Logz.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Muon/pic/png/Long_Muon-MVAOutVDLL-Signal_Logz.png" /></td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Muon/pic/png/Long_MuonMVAOut_Liny.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Muon/pic/png/Long_MuonMVAOut_Logy.png" /></td>
#
# </tr>
#
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Muon/pic/png/MVAEffForDLLCut/Long_Muon-MVAEff-DLLCut-8.000.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Muon/pic/png/MVAEffForDLLCut/Long_Muon-MVAEff-DLLCut-2.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Muon/pic/png/MVAEffForDLLCut/Long_Muon-MVAEff-DLLCut2.000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Muon/pic/png/MVAEffForDLLCut/Long_Muon-MVAEff-DLLCut8.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td colspan=2 align='center'>
# Efficiency for the each MVA Output and CombDLL cut values is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_MVA\_\_and\_CombDLL\_cuts}}{N_{total\_tracks\_passed\_the\_CombDLL\_cut}} * 100\% $$
#
# Each ghaph above corresponds one CombDLL cut value.
#
# </td>
#
#
# </tr>
# </tbody>
# </table>
#
# __________
#
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Muon/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Muon-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Muon/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Muon-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Muon/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Muon-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Muon/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Muon-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each momentum bin separately. Efficiency in particular momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
#
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Muon/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Muon-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Muon/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Muon-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Muon/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Muon-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Muon/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Muon-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each transverse momentum bin separately. Efficiency in particular transverse momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Flatness_SignalMVAEffVTrackP_Long_Muon.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Flatness_SignalMVAEffVTrackPt_Long_Muon.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Each curve corresponds just one MVA Output cut value which provides particular overall MVA Efficiency value for a signal particle. Each point of the curves means the MVA Efficiency value for a signal particle in this particular Momentum/Transverse Momentum bin.
# </td>
# </tbody>
# </table>
#
# #### CvM tests:

# %%
flatness.loc[['Muon']]
# Out:
#       TrackP  TrackPt  P_Conf_level  Pt_Conf_level
# Muon   0.031    0.043         0.001          0.001

# %% [markdown]
# ### Long Proton

# %% [markdown]
# <table>
# <tbody>
#
# <tr>
#
# <td width="50%">
# <img src= "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Proton/pic/png/Long_Proton-IDEff_V_OverallMisIDEff_Logy.png"/>
#
# The signal and background (Overal MissID) efficiencies are calculated for each of CombDLL and MVA Output cuts. The efficiency for the particular cut is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_cut}}{N_{total\_tracks}} * 100\% $$
# </td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Proton/pic/png/Long_Proton-PurityVMVAOut.png" />
#
# The purity of the signal tracks for the particular MVA Output cut value is calculated by the following expression:
#
# $$ Purity_{cut} = \frac{N_{signal\_tracks\_passed\_the\_cut}}{N_{all\_tracks\_passed\_the\_cut}} * 100\% $$
# $ $
#
# </td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Proton/pic/png/Long_Proton-MVAOutVDLL-Background_Logz.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Proton/pic/png/Long_Proton-MVAOutVDLL-Signal_Logz.png" /></td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Proton/pic/png/Long_ProtonMVAOut_Liny.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Proton/pic/png/Long_ProtonMVAOut_Logy.png" /></td>
#
# </tr>
#
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Proton/pic/png/MVAEffForDLLCut/Long_Proton-MVAEff-DLLCut-8.000.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Proton/pic/png/MVAEffForDLLCut/Long_Proton-MVAEff-DLLCut-2.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Proton/pic/png/MVAEffForDLLCut/Long_Proton-MVAEff-DLLCut2.000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Proton/pic/png/MVAEffForDLLCut/Long_Proton-MVAEff-DLLCut8.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td colspan=2 align='center'>
# Efficiency for the each MVA Output and CombDLL cut values is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_MVA\_\_and\_CombDLL\_cuts}}{N_{total\_tracks\_passed\_the\_CombDLL\_cut}} * 100\% $$
#
# Each ghaph above corresponds one CombDLL cut value.
#
# </td>
#
#
# </tr>
# </tbody>
# </table>
#
# __________
#
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Proton/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Proton-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Proton/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Proton-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Proton/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Proton-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Proton/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Proton-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each momentum bin separately. Efficiency in particular momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
#
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Proton/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Proton-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Proton/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Proton-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Proton/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Proton-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Proton/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Proton-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each transverse momentum bin separately. Efficiency in particular transverse momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Flatness_SignalMVAEffVTrackP_Long_Proton.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Flatness_SignalMVAEffVTrackPt_Long_Proton.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Each curve corresponds just one MVA Output cut value which provides particular overall MVA Efficiency value for a signal particle. Each point of the curves means the MVA Efficiency value for a signal particle in this particular Momentum/Transverse Momentum bin.
# </td>
# </tbody>
# </table>
#
# #### CvM tests:

# %%
flatness.loc[['Proton']]
# Out:
#         TrackP  TrackPt  P_Conf_level  Pt_Conf_level
# Proton   0.038    0.046         0.001          0.001

# %% [markdown]
# # Long Pion
# <table>
# <tbody>
#
# <tr>
#
# <td width="50%">
# <img src= "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Pion/pic/png/Long_Pion-IDEff_V_OverallMisIDEff_Logy.png"/>
#
# The signal and background (Overal MissID) efficiencies are calculated for each of CombDLL and MVA Output cuts. The efficiency for the particular cut is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_cut}}{N_{total\_tracks}} * 100\% $$
# </td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Pion/pic/png/Long_Pion-PurityVMVAOut.png" />
#
# The purity of the signal tracks for the particular MVA Output cut value is calculated by the following expression:
#
# $$ Purity_{cut} = \frac{N_{signal\_tracks\_passed\_the\_cut}}{N_{all\_tracks\_passed\_the\_cut}} * 100\% $$
# $ $
#
# </td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Pion/pic/png/Long_Pion-MVAOutVDLL-Background_Logz.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Pion/pic/png/Long_Pion-MVAOutVDLL-Signal_Logz.png" /></td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Pion/pic/png/Long_PionMVAOut_Liny.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Pion/pic/png/Long_PionMVAOut_Logy.png" /></td>
#
# </tr>
#
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Pion/pic/png/MVAEffForDLLCut/Long_Pion-MVAEff-DLLCut-8.000.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Pion/pic/png/MVAEffForDLLCut/Long_Pion-MVAEff-DLLCut-2.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Pion/pic/png/MVAEffForDLLCut/Long_Pion-MVAEff-DLLCut2.000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Pion/pic/png/MVAEffForDLLCut/Long_Pion-MVAEff-DLLCut8.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td colspan=2 align='center'>
# Efficiency for the each MVA Output and CombDLL cut values is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_MVA\_\_and\_CombDLL\_cuts}}{N_{total\_tracks\_passed\_the\_CombDLL\_cut}} * 100\% $$
#
# Each ghaph above corresponds one CombDLL cut value.
#
# </td>
#
#
# </tr>
# </tbody>
# </table>
#
# __________
#
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Pion/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Pion-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Pion/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Pion-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Pion/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Pion-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Pion/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Pion-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each momentum bin separately. Efficiency in particular momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
#
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Pion/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Pion-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Pion/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Pion-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Pion/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Pion-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Pion/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Pion-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each transverse momentum bin separately. Efficiency in particular transverse momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Flatness_SignalMVAEffVTrackP_Long_Pion.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Flatness_SignalMVAEffVTrackPt_Long_Pion.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Each curve corresponds just one MVA Output cut value which provides particular overall MVA Efficiency value for a signal particle. Each point of the curves means the MVA Efficiency value for a signal particle in this particular Momentum/Transverse Momentum bin.
# </td>
# </tbody>
# </table>
#
# #### CvM tests:

# %%
flatness.loc[['Pion']]
# Out:
#       TrackP  TrackPt  P_Conf_level  Pt_Conf_level
# Pion   0.018    0.015         0.001          0.001

# %% [markdown]
# ### Long Ghost

# %% [markdown]
# <table>
# <tbody>
#
# <tr>
#
# <td width="50%">
# <img src= "baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Ghost/pic/png/Long_Ghost-IDEff_V_OverallMisIDEff_Logy.png"/>
#
# The signal and background (Overal MissID) efficiencies are calculated for each of CombDLL and MVA Output cuts. The efficiency for the particular cut is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_cut}}{N_{total\_tracks}} * 100\% $$
# </td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Ghost/pic/png/Long_Ghost-PurityVMVAOut.png" />
#
# The purity of the signal tracks for the particular MVA Output cut value is calculated by the following expression:
#
# $$ Purity_{cut} = \frac{N_{signal\_tracks\_passed\_the\_cut}}{N_{all\_tracks\_passed\_the\_cut}} * 100\% $$
# $ $
#
# </td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Ghost/pic/png/Long_Ghost-MVAOutVDLL-Background_Logz.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Ghost/pic/png/Long_Ghost-MVAOutVDLL-Signal_Logz.png" /></td>
#
# </tr>
#
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Ghost/pic/png/Long_GhostMVAOut_Liny.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Ghost/pic/png/Long_GhostMVAOut_Logy.png" /></td>
#
# </tr>
#
# </tbody>
# </table>
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Ghost/pic/png/MVAEffForDLLCut/Long_Ghost-MVAEff-DLLCut-8.000.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Ghost/pic/png/MVAEffForDLLCut/Long_Ghost-MVAEff-DLLCut-2.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Ghost/pic/png/MVAEffForDLLCut/Long_Ghost-MVAEff-DLLCut2.000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Ghost/pic/png/MVAEffForDLLCut/Long_Ghost-MVAEff-DLLCut8.000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td colspan=2 align='center'>
# Efficiency for the each MVA Output and CombDLL cut values is determined by the following expression:
#
# $$ Efficiency_{cut} = \frac{N_{tracks\_passed\_the\_MVA\_\_and\_CombDLL\_cuts}}{N_{total\_tracks\_passed\_the\_CombDLL\_cut}} * 100\% $$
#
# Each ghaph above corresponds one CombDLL cut value.
#
# </td>
#
#
# </tr>
# </tbody>
# </table>
#
# __________
#
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Ghost/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Ghost-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Ghost/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Ghost-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Ghost/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Ghost-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Ghost/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Ghost-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each momentum bin separately. Efficiency in particular momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
#
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Ghost/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Ghost-MVACut0.0100.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Ghost/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Ghost-MVACut0.1000.png" /></td>
#
# </tr>
#
# <tr>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Ghost/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Ghost-MVACut0.5000.png" /></td>
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Ghost/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Ghost-MVACut0.9000.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Efficiencies is calculated for the each transverse momentum bin separately. Efficiency in particular transverse momentum bin for the each MVA Output value is calculated by the following expression:
#
# $$ Efficiency_{for\_cut\_in\_bin} = \frac{N_{tracks\_in\_bin\_passed\_the\_MVA\_cut}}{N_{total\_tracks\_in\_bin}} * 100\% $$
#
# Each ghaph above corresponds one MVA cut value.
#
# </td>
# </tbody>
# </table>
#
#
# __________
#
# <table>
# <tbody>
# <tr>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Flatness_SignalMVAEffVTrackP_Long_Ghost.png" /></td>
#
#
# <td><img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/multiclass/Long/XGBoost/verbose=0;missing=-999.0;scale_pos_weight=1.0;random_state=0;num_feature=None;base_score=0.5;n_estimators=1000;subsample=0.5;eta=0.01;min_child_weight=50;colsample=0.7;max_depth=8;gamma=None;nthreads=4;balanced_data_235449/Flatness_SignalMVAEffVTrackPt_Long_Ghost.png" /></td>
#
# </tr>
#
# <td colspan=2 align='center'>
# Each curve corresponds just one MVA Output cut value which provides particular overall MVA Efficiency value for a signal particle. Each point of the curves means the MVA Efficiency value for a signal particle in this particular Momentum/Transverse Momentum bin.
# </td>
# </tbody>
# </table>
#
# #### CvM tests:

# %%
flatness.loc[['Ghost']]
# Out:
#        TrackP  TrackPt  P_Conf_level  Pt_Conf_level
# Ghost   0.004    0.013         0.001          0.001
