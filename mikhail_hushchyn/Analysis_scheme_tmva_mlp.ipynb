# %% [markdown]
# # LHCb Particle Identification

# %% [markdown]
# # Baseline

# %% [markdown]
# For the baseline repeating the following configuration was choosen:
#
# *Train config:* TrainPhysTks-EvalPhysTks-NoReweight <br>
# *Net config:* TMVA-Run2-NoTkLikCDVelodEdx <br>
# *GhostAccFrac:* 1.0 <br>
# *Training data:* Mixture <br>
# *Data files:* MC2015Sim09Dev03 <br>

# %% [markdown]
# ## TMVA MLP

# %% [markdown]
# A list of the classifier's parameters is shown below:
#
# *Method:* kMLP <br>
# *Factory_options:* V:!Silent:!Color:!DrawProgressBar <br>
# *H:* true <br>
# *V:* true <br>
# *EpochMonitoring:* true <br>
# *HiddenLayers:* 1.2 x len(features) <br>
# *UseRegulator:* true <br>
# *ConvergenceImprove:* 1e-16 <br>
# *ConvergenceTests:* 15 <br>
# *VarTransform:* Norm <br>
# *NCycles:* 750 <br>
# *NeuronType:* sigmoid <br>
# *TrainingMethod:* BP <br>
# *EstimatorType:* CE <br>

# %% [markdown]
# ## Overal quality

# %% [markdown]
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/TMVA/kMLP/overall_roc_auc.png" />
#
#
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/TMVA/kMLP/class_vs_class_roc_auc_matrix.png" />

# %% [markdown]
# ### Long Electron

# %% [markdown]
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/TMVA/kMLP/pic/png/Long_Electron-IDEff_V_OverallMissIDEff_Logy.png" />
#
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/TMVA/kMLP/pic/png/Long_Electron-PurityVMVAOut.png" />
#
# Background:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/TMVA/kMLP/pic/png/Long_Electron-MVAOutVDLL-Background_Logz.png" />
#
# Signal:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/TMVA/kMLP/pic/png/Long_Electron-MVAOutVDLL-Signal_Logz.png" />
#
# Liny:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/TMVA/kMLP/pic/png/Long_ElectronMVAOut_Liny.png" />
#
# Logy:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/TMVA/kMLP/pic/png/Long_ElectronMVAOut_Logy.png" />
#
# __________
#
# DLL cut -8.0:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Electron-MVAEff-DLLCut-8.000.png" />
#
# DLL cut 0.0:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Electron-MVAEff-DLLCut0.000.png" />
#
#
# DLL cut 8.0:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Electron-MVAEff-DLLCut8.000.png" />
#
# __________
#
# MVA cut 0.6:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Electron-MVACut0.6000.png" />
#
# MVA cut 0.8:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Electron-MVACut0.8000.png" />
#
#
# MVA cut 0.95:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Electron-MVACut0.9500.png" />
#
# __________
#
# MVA cut 0.6:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Electron-MVACut0.6000.png" />
#
# MVA cut 0.8:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Electron-MVACut0.8000.png" />
#
#
# MVA cut 0.95:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Electron/Long/TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Electron-MVACut0.9500.png" />

# %% [markdown]
# ### Long Pion

# %% [markdown]
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/TMVA/kMLP/pic/png/Long_Pion-IDEff_V_OverallMissIDEff_Logy.png" />
#
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/TMVA/kMLP/pic/png/Long_Pion-PurityVMVAOut.png" />
#
# Background:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/TMVA/kMLP/pic/png/Long_Pion-MVAOutVDLL-Background_Logz.png" />
#
# Signal:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/TMVA/kMLP/pic/png/Long_Pion-MVAOutVDLL-Signal_Logz.png" />
#
# Liny:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/TMVA/kMLP/pic/png/Long_PionMVAOut_Liny.png" />
#
# Logy:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/TMVA/kMLP/pic/png/Long_PionMVAOut_Logy.png" />
#
# __________
#
# DLL cut -8.0:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Pion-MVAEff-DLLCut-8.000.png" />
#
# DLL cut 0.0:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Pion-MVAEff-DLLCut0.000.png" />
#
#
# DLL cut 8.0:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Pion-MVAEff-DLLCut8.000.png" />
#
# __________
#
# MVA cut 0.6:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Pion-MVACut0.6000.png" />
#
# MVA cut 0.8:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Pion-MVACut0.8000.png" />
#
#
# MVA cut 0.95:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Pion-MVACut0.9500.png" />
#
# __________
#
# MVA cut 0.6:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Pion-MVACut0.6000.png" />
#
# MVA cut 0.8:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Pion-MVACut0.8000.png" />
#
#
# MVA cut 0.95:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Pion/Long/TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Pion-MVACut0.9500.png" />

# %% [markdown]
# ### Long Kaon

# %% [markdown]
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/TMVA/kMLP/pic/png/Long_Kaon-IDEff_V_OverallMissIDEff_Logy.png" />
#
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/TMVA/kMLP/pic/png/Long_Kaon-PurityVMVAOut.png" />
#
# Background:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/TMVA/kMLP/pic/png/Long_Kaon-MVAOutVDLL-Background_Logz.png" />
#
# Signal:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/TMVA/kMLP/pic/png/Long_Kaon-MVAOutVDLL-Signal_Logz.png" />
#
# Liny:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/TMVA/kMLP/pic/png/Long_KaonMVAOut_Liny.png" />
#
# Logy:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/TMVA/kMLP/pic/png/Long_KaonMVAOut_Logy.png" />
#
# __________
#
# DLL cut -8.0:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Kaon-MVAEff-DLLCut-8.000.png" />
#
# DLL cut 0.0:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Kaon-MVAEff-DLLCut0.000.png" />
#
#
# DLL cut 8.0:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Kaon-MVAEff-DLLCut8.000.png" />
#
# __________
#
# MVA cut 0.6:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Kaon-MVACut0.6000.png" />
#
# MVA cut 0.8:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Kaon-MVACut0.8000.png" />
#
#
# MVA cut 0.95:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Kaon-MVACut0.9500.png" />
#
# __________
#
# MVA cut 0.6:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Kaon-MVACut0.6000.png" />
#
# MVA cut 0.8:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Kaon-MVACut0.8000.png" />
#
#
# MVA cut 0.95:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Kaon/Long/TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Kaon-MVACut0.9500.png" />

# %% [markdown]
# ### Long Muon

# %% [markdown]
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/TMVA/kMLP/pic/png/Long_Muon-IDEff_V_OverallMissIDEff_Logy.png" />
#
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/TMVA/kMLP/pic/png/Long_Muon-PurityVMVAOut.png" />
#
# Background:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/TMVA/kMLP/pic/png/Long_Muon-MVAOutVDLL-Background_Logz.png" />
#
# Signal:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/TMVA/kMLP/pic/png/Long_Muon-MVAOutVDLL-Signal_Logz.png" />
#
# Liny:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/TMVA/kMLP/pic/png/Long_MuonMVAOut_Liny.png" />
#
# Logy:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/TMVA/kMLP/pic/png/Long_MuonMVAOut_Logy.png" />
#
# __________
#
# DLL cut -8.0:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Muon-MVAEff-DLLCut-8.000.png" />
#
# DLL cut 0.0:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Muon-MVAEff-DLLCut0.000.png" />
#
#
# DLL cut 8.0:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Muon-MVAEff-DLLCut8.000.png" />
#
# __________
#
# MVA cut 0.6:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Muon-MVACut0.6000.png" />
#
# MVA cut 0.8:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Muon-MVACut0.8000.png" />
#
#
# MVA cut 0.95:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Muon-MVACut0.9500.png" />
#
# __________
#
# MVA cut 0.6:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Muon-MVACut0.6000.png" />
#
# MVA cut 0.8:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Muon-MVACut0.8000.png" />
#
#
# MVA cut 0.95:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Muon/Long/TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Muon-MVACut0.9500.png" />

# %% [markdown]
# ### Long Proton

# %% [markdown]
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/TMVA/kMLP/pic/png/Long_Proton-IDEff_V_OverallMissIDEff_Logy.png" />
#
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/TMVA/kMLP/pic/png/Long_Proton-PurityVMVAOut.png" />
#
# Background:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/TMVA/kMLP/pic/png/Long_Proton-MVAOutVDLL-Background_Logz.png" />
#
# Signal:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/TMVA/kMLP/pic/png/Long_Proton-MVAOutVDLL-Signal_Logz.png" />
#
# Liny:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/TMVA/kMLP/pic/png/Long_ProtonMVAOut_Liny.png" />
#
# Logy:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/TMVA/kMLP/pic/png/Long_ProtonMVAOut_Logy.png" />
#
# __________
#
# DLL cut -8.0:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Proton-MVAEff-DLLCut-8.000.png" />
#
# DLL cut 0.0:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Proton-MVAEff-DLLCut0.000.png" />
#
#
# DLL cut 8.0:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Proton-MVAEff-DLLCut8.000.png" />
#
# __________
#
# MVA cut 0.6:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Proton-MVACut0.6000.png" />
#
# MVA cut 0.8:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Proton-MVACut0.8000.png" />
#
#
# MVA cut 0.95:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Proton-MVACut0.9500.png" />
#
# __________
#
# MVA cut 0.6:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Proton-MVACut0.6000.png" />
#
# MVA cut 0.8:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Proton-MVACut0.8000.png" />
#
#
# MVA cut 0.95:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Proton/Long/TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Proton-MVACut0.9500.png" />

# %% [markdown]
# ### Long Ghost

# %% [markdown]
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/TMVA/kMLP/pic/png/Long_Ghost-IDEff_V_OverallMissIDEff_Logy.png" />
#
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/TMVA/kMLP/pic/png/Long_Ghost-PurityVMVAOut.png" />
#
# Background:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/TMVA/kMLP/pic/png/Long_Ghost-MVAOutVDLL-Background_Logz.png" />
#
# Signal:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/TMVA/kMLP/pic/png/Long_Ghost-MVAOutVDLL-Signal_Logz.png" />
#
# Liny:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/TMVA/kMLP/pic/png/Long_GhostMVAOut_Liny.png" />
#
# Logy:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/TMVA/kMLP/pic/png/Long_GhostMVAOut_Logy.png" />
#
# __________
#
# DLL cut -8.0:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Ghost-MVAEff-DLLCut-8.000.png" />
#
# DLL cut 0.0:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Ghost-MVAEff-DLLCut0.000.png" />
#
#
# DLL cut 8.0:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/TMVA/kMLP/pic/png/MVAEffForDLLCut/Long_Ghost-MVAEff-DLLCut8.000.png" />
#
# __________
#
# MVA cut 0.6:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Ghost-MVACut0.6000.png" />
#
# MVA cut 0.8:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Ghost-MVACut0.8000.png" />
#
#
# MVA cut 0.95:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/TMVA/kMLP/pic/png/MVAEffVTrackP/MVAEffVTrackP_Long_Ghost-MVACut0.9500.png" />
#
# __________
#
# MVA cut 0.6:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Ghost-MVACut0.6000.png" />
#
# MVA cut 0.8:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Ghost-MVACut0.8000.png" />
#
#
# MVA cut 0.95:
# <img src="baseline/MC2015Sim09Dev03/TrainMixture/TrainPhysTks-EvalPhysTks-NoReweight/GhostAccFrac1.0/Ghost/Long/TMVA/kMLP/pic/png/MVAEffVTrackPt/MVAEffVTrackPt_Long_Ghost-MVACut0.9500.png" />
